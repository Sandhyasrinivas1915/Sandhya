# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandhyasrinivas1915/Sandhya/blob/main/NLP6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = "Google announced a new AI research center in Hyderabad last year."

doc = nlp(text)

# %%
tokens = [token.text for token in doc]
print(tokens)
# Out:
# ['Google', 'announced', 'a', 'new', 'AI', 'research', 'center', 'in', 'Hyderabad', 'last', 'year', '.']

# %%
filtered_tokens = [token.text for token in doc if not token.is_stop and not token.is_punct]
print(filtered_tokens)
# Out:
# ['Google', 'announced', 'new', 'AI', 'research', 'center', 'Hyderabad', 'year']

# %%
lemmas = [(token.text, token.lemma_) for token in doc]
print(lemmas)
# Out:
# [('Google', 'Google'), ('announced', 'announce'), ('a', 'a'), ('new', 'new'), ('AI', 'AI'), ('research', 'research'), ('center', 'center'), ('in', 'in'), ('Hyderabad', 'Hyderabad'), ('last', 'last'), ('year', 'year'), ('.', '.')]

# %%
pos_tags = [(token.text, token.pos_) for token in doc]
print(pos_tags)
# Out:
# [('Google', 'PROPN'), ('announced', 'VERB'), ('a', 'DET'), ('new', 'ADJ'), ('AI', 'PROPN'), ('research', 'NOUN'), ('center', 'NOUN'), ('in', 'ADP'), ('Hyderabad', 'PROPN'), ('last', 'ADJ'), ('year', 'NOUN'), ('.', 'PUNCT')]

# %%
entities = [(ent.text, ent.label_) for ent in doc.ents]
print(entities)
# Out:
# [('Google', 'ORG'), ('AI', 'GPE'), ('Hyderabad', 'GPE'), ('last year', 'DATE')]

# %%
dependencies = [(token.text, token.dep_, token.head.text) for token in doc]
print(dependencies)
# Out:
# [('Google', 'nsubj', 'announced'), ('announced', 'ROOT', 'announced'), ('a', 'det', 'center'), ('new', 'amod', 'center'), ('AI', 'compound', 'center'), ('research', 'compound', 'center'), ('center', 'dobj', 'announced'), ('in', 'prep', 'center'), ('Hyderabad', 'pobj', 'in'), ('last', 'amod', 'year'), ('year', 'npadvmod', 'announced'), ('.', 'punct', 'announced')]
